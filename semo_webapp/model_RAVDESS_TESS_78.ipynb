# %%
# Keras
import keras
from keras import regularizers
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Embedding, LSTM
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

# sklearn
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Other  
import librosa
import librosa.display
import json
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
import pandas as pd
import seaborn as sns
import glob 
import os
import pickle
import IPython.display as ipd  # To play sound in the notebook

# %% [raw]
# - the RAVDESS dataset files (Folders Actor_01 to Actor_24
# - the TESS dataset renamed files (Folders Actor_25 and Actor_26)

# %%
dataframe=pd.read_csv('./mfcc_data.csv')
print(dataframe.shape)
dataframe.head()
# Out:
# (5252, 44)
#   gender  emotion  actor                                               path  \
# 0   male  neutral      1  F:/ravdess_tess/Actor_01/03-01-01-01-01-01-01.wav
# 1   male  neutral      1  F:/ravdess_tess/Actor_01/03-01-01-01-01-02-01.wav
# 2   male  neutral      1  F:/ravdess_tess/Actor_01/03-01-01-01-02-01-01.wav
# 3   male  neutral      1  F:/ravdess_tess/Actor_01/03-01-01-01-02-02-01.wav
# 4   male     calm      1  F:/ravdess_tess/Actor_01/03-01-02-01-01-01-01.wav
#
#             0          1         2          3         4         5  ...  \
# 0 -700.398926  58.630211 -3.025852  16.040241  4.248529  3.869935  ...
# 1 -695.557861  59.240154 -5.372777  19.776367  5.200387  3.324630  ...
# 2 -694.004333  61.496510 -3.262743  16.971298  2.142968  4.266798  ...
# 3 -687.513367  59.441540 -0.703714  16.645708  3.730826  6.181194  ...
# 4 -729.980164  66.515892 -0.941984  19.070974  4.297080  5.635082  ...
#
#          30        31        32        33        34        35        36  \
# 0 -1.411359 -2.769772 -2.042009 -2.522663 -2.507448 -2.250499 -0.381507
# 1 -1.055913 -3.102514 -1.697880 -2.922661 -2.544465 -1.289832 -0.797254
# 2 -1.382858 -2.590943 -1.929074 -2.390322 -2.269381 -2.486079 -0.589257
# 3 -2.024173 -2.586190 -2.420421 -3.243219 -2.762588 -1.960003 -0.453890
# 4 -1.519869 -1.797158 -1.296814 -3.051891 -1.131349 -1.063672 -1.141021
#
#          37        38        39
# 0 -2.481059 -2.791023 -2.244865
# 1 -3.586074 -2.706395 -2.812933
# 2 -3.248326 -2.979813 -2.769281
# 3 -2.976706 -2.914763 -3.909605
# 4 -2.373389 -3.204345 -3.363193
#
# [5 rows x 44 columns]

# %%
label_encoder= LabelEncoder()
dataframe['emotion']= label_encoder.fit_transform(dataframe['emotion'])
dataframe['emotion'].unique()
dataframe.head(50)
# Out:
#    gender  emotion  actor                                               path  \
# 0    male        5      1  F:/ravdess_tess/Actor_01/03-01-01-01-01-01-01.wav
# 1    male        5      1  F:/ravdess_tess/Actor_01/03-01-01-01-01-02-01.wav
# 2    male        5      1  F:/ravdess_tess/Actor_01/03-01-01-01-02-01-01.wav
# 3    male        5      1  F:/ravdess_tess/Actor_01/03-01-01-01-02-02-01.wav
# 4    male        1      1  F:/ravdess_tess/Actor_01/03-01-02-01-01-01-01.wav
# 5    male        1      1  F:/ravdess_tess/Actor_01/03-01-02-01-01-02-01.wav
# 6    male        1      1  F:/ravdess_tess/Actor_01/03-01-02-01-02-01-01.wav
# 7    male        1      1  F:/ravdess_tess/Actor_01/03-01-02-01-02-02-01.wav
# 8    male        1      1  F:/ravdess_tess/Actor_01/03-01-02-02-01-01-01.wav
# 9    male        1      1  F:/ravdess_tess/Actor_01/03-01-02-02-01-02-01.wav
# 10   male        1      1  F:/ravdess_tess/Actor_01/03-01-02-02-02-01-01.wav
# 11   male        1      1  F:/ravdess_tess/Actor_01/03-01-02-02-02-02-01.wav
# 12   male        4      1  F:/ravdess_tess/Actor_01/03-01-03-01-01-01-01.wav
# 13   male        4      1  F:/ravdess_tess/Actor_01/03-01-03-01-01-02-01.wav
# 14   male        4      1  F:/ravdess_tess/Actor_01/03-01-03-01-02-01-01.wav
# 15   male        4      1  F:/ravdess_tess/Actor_01/03-01-03-01-02-02-01.wav
# 16   male        4      1  F:/ravdess_tess/Actor_01/03-01-03-02-01-01-01.wav
# 17   male        4      1  F:/ravdess_tess/Actor_01/03-01-03-02-01-02-01.wav
# 18   male        4      1  F:/ravdess_tess/Actor_01/03-01-03-02-02-01-01.wav
# 19   male        4      1  F:/ravdess_tess/Actor_01/03-01-03-02-02-02-01.wav
# 20   male        6      1  F:/ravdess_tess/Actor_01/03-01-04-01-01-01-01.wav
# 21   male        6      1  F:/ravdess_tess/Actor_01/03-01-04-01-01-02-01.wav
# 22   male        6      1  F:/ravdess_tess/Actor_01/03-01-04-01-02-01-01.wav
# 23   male        6      1  F:/ravdess_tess/Actor_01/03-01-04-01-02-02-01.wav
# 24   male        6      1  F:/ravdess_tess/Actor_01/03-01-04-02-01-01-01.wav
# 25   male        6      1  F:/ravdess_tess/Actor_01/03-01-04-02-01-02-01.wav
# 26   male        6      1  F:/ravdess_tess/Actor_01/03-01-04-02-02-01-01.wav
# 27   male        6      1  F:/ravdess_tess/Actor_01/03-01-04-02-02-02-01.wav
# 28   male        0      1  F:/ravdess_tess/Actor_01/03-01-05-01-01-01-01.wav
# 29   male        0      1  F:/ravdess_tess/Actor_01/03-01-05-01-01-02-01.wav
# 30   male        0      1  F:/ravdess_tess/Actor_01/03-01-05-01-02-01-01.wav
# 31   male        0      1  F:/ravdess_tess/Actor_01/03-01-05-01-02-02-01.wav
# 32   male        0      1  F:/ravdess_tess/Actor_01/03-01-05-02-01-01-01.wav
# 33   male        0      1  F:/ravdess_tess/Actor_01/03-01-05-02-01-02-01.wav
# 34   male        0      1  F:/ravdess_tess/Actor_01/03-01-05-02-02-01-01.wav
# 35   male        0      1  F:/ravdess_tess/Actor_01/03-01-05-02-02-02-01.wav
# 36   male        3      1  F:/ravdess_tess/Actor_01/03-01-06-01-01-01-01.wav
# 37   male        3      1  F:/ravdess_tess/Actor_01/03-01-06-01-01-02-01.wav
# 38   male        3      1  F:/ravdess_tess/Actor_01/03-01-06-01-02-01-01.wav
# 39   male        3      1  F:/ravdess_tess/Actor_01/03-01-06-01-02-02-01.wav
# 40   male        3      1  F:/ravdess_tess/Actor_01/03-01-06-02-01-01-01.wav
# 41   male        3      1  F:/ravdess_tess/Actor_01/03-01-06-02-01-02-01.wav
# 42   male        3      1  F:/ravdess_tess/Actor_01/03-01-06-02-02-01-01.wav
# 43   male        3      1  F:/ravdess_tess/Actor_01/03-01-06-02-02-02-01.wav
# 44   male        2      1  F:/ravdess_tess/Actor_01/03-01-07-01-01-01-01.wav
# 45   male        2      1  F:/ravdess_tess/Actor_01/03-01-07-01-01-02-01.wav
# 46   male        2      1  F:/ravdess_tess/Actor_01/03-01-07-01-02-01-01.wav
# 47   male        2      1  F:/ravdess_tess/Actor_01/03-01-07-01-02-02-01.wav
# 48   male        2      1  F:/ravdess_tess/Actor_01/03-01-07-02-01-01-01.wav
# 49   male        2      1  F:/ravdess_tess/Actor_01/03-01-07-02-01-02-01.wav
#
#              0          1          2          3          4          5  ...  \
# 0  -700.398926  58.630211  -3.025852  16.040241   4.248529   3.869935  ...
# 1  -695.557861  59.240154  -5.372777  19.776367   5.200387   3.324630  ...
# 2  -694.004333  61.496510  -3.262743  16.971298   2.142968   4.266798  ...
# 3  -687.513367  59.441540  -0.703714  16.645708   3.730826   6.181194  ...
# 4  -729.980164  66.515892  -0.941984  19.070974   4.297080   5.635082  ...
# 5  -710.053589  70.618843  -1.556971  14.907612   6.146932   4.515686  ...
# 6  -700.310669  69.606895  -3.506135  17.969084   1.762492   6.918274  ...
# 7  -701.648193  73.041389  -3.148731  17.866001   4.322560   5.934957  ...
# 8  -737.635132  75.560745  -0.719248  18.717581   4.626381   6.345685  ...
# 9  -701.305725  72.316086  -5.354832  16.675138   2.270264   5.004624  ...
# 10 -708.586609  74.851303  -1.195068  17.735134   0.068686  11.248456  ...
# 11 -694.987915  71.004539  -9.133077  20.062321   1.412678   8.076330  ...
# 12 -648.592712  66.903084  -8.116306  16.228350   0.731063   0.456466  ...
# 13 -633.644653  66.226807  -8.990109  18.561934   3.542567   1.270927  ...
# 14 -658.780762  65.886093  -5.957528  16.460464  -1.589720   3.112185  ...
# 15 -655.902344  61.638367  -4.100128  22.738585  -1.642009   4.545904  ...
# 16 -599.672485  53.605961 -10.383512   9.909241  -5.438645   2.795510  ...
# 17 -562.437256  58.487423 -15.078140   8.968288  -0.937185   1.341997  ...
# 18 -520.787354  52.357952 -14.498966  12.008779  -4.210526   1.694555  ...
# 19 -542.508118  54.402779 -13.658028  11.467112  -5.522990   0.883293  ...
# 20 -683.593933  64.737061  -5.831736  17.984890   3.178772   0.604821  ...
# 21 -701.901917  69.507591  -5.056865  20.400423   4.777226   3.127671  ...
# 22 -738.170105  64.203064  -7.184046  17.684679   3.061616   1.608481  ...
# 23 -714.356140  63.296867  -2.934872  19.169828   2.566622   3.110872  ...
# 24 -672.792542  66.598816  -3.157140  20.832615   3.979562   1.827544  ...
# 25 -630.109802  54.673798  -8.620368  14.140103   0.200940  -0.271139  ...
# 26 -622.661438  58.430439  -9.114211  17.023947   0.759873   0.289106  ...
# 27 -609.009583  55.279327  -8.501711  17.632816  -1.843139   0.859120  ...
# 28 -549.178040  46.897011 -10.341229  16.867872  -5.494266   1.123966  ...
# 29 -529.751282  45.074440 -10.304814  12.880027  -8.027543   0.794448  ...
# 30 -573.594360  49.186203  -5.265390  15.504213  -3.937147   1.563768  ...
# 31 -533.833069  48.567627  -7.105445  12.736706  -3.998675   0.366486  ...
# 32 -352.822998  35.329006 -25.370354   6.043685 -16.442394   0.548191  ...
# 33 -372.951294  29.057878 -25.434685   9.737882 -16.596886   0.673909  ...
# 34 -405.536560  35.899506 -21.589779  10.615099 -12.247245   1.386372  ...
# 35 -308.164551  28.425911 -26.285158   2.900836 -16.304438  -1.037180  ...
# 36 -598.683411  62.780674  -2.467007  18.964651   4.042611   1.873504  ...
# 37 -606.303467  59.480270 -10.236553  13.245481   0.449186  -0.226530  ...
# 38 -627.423523  64.717865   3.064753  23.543562   6.135674   8.293139  ...
# 39 -627.439880  65.294785  -8.142695  20.094799   2.217384   4.312599  ...
# 40 -443.352600  58.352879 -18.573046  11.043633  -3.890486  11.330253  ...
# 41 -407.093323  47.092426 -21.870584   1.010306  -2.150194   3.673134  ...
# 42 -373.149506  44.259701 -20.381495   4.007766 -10.469775   3.453642  ...
# 43 -431.010162  50.815083 -21.013645   4.297768  -5.988181   7.062822  ...
# 44 -651.088684  68.844818  -8.057979  15.844139  -0.711339   4.903634  ...
# 45 -630.391663  58.328529  -5.173175  10.055345  -1.708316   4.506625  ...
# 46 -671.044861  76.436508  -3.081492  17.535433  -2.986246   8.032582  ...
# 47 -672.501221  59.384579  -5.431530  14.982107  -4.445535   7.734421  ...
# 48 -493.550354  49.198475 -12.122496  -0.623901 -14.331903   2.769516  ...
# 49 -494.616516  40.265575 -14.051857   6.806215 -13.388750  -1.801273  ...
#
#           30        31        32        33        34        35        36  \
# 0  -1.411359 -2.769772 -2.042009 -2.522663 -2.507448 -2.250499 -0.381507
# 1  -1.055913 -3.102514 -1.697880 -2.922661 -2.544465 -1.289832 -0.797254
# 2  -1.382858 -2.590943 -1.929074 -2.390322 -2.269381 -2.486079 -0.589257
# 3  -2.024173 -2.586190 -2.420421 -3.243219 -2.762588 -1.960003 -0.453890
# 4  -1.519869 -1.797158 -1.296814 -3.051891 -1.131349 -1.063672 -1.141021
# 5  -2.750205 -2.973075 -2.723013 -4.105726 -3.067898 -1.945277 -1.405727
# 6  -2.609689 -2.311951 -1.969841 -3.713224 -3.606847 -2.651424 -1.539352
# 7  -2.940772 -2.292238 -1.674364 -3.187426 -2.925244 -2.374242 -0.633166
# 8  -2.812648 -3.633809 -3.053499 -2.879167 -4.523717 -0.313282 -2.087159
# 9  -3.309166 -3.141019 -3.548249 -3.604880 -4.542142 -1.873123 -1.388900
# 10 -3.418609 -2.769543 -2.184686 -3.585048 -3.665161 -1.129430 -0.910551
# 11 -3.821226 -3.548358 -3.300373 -3.332084 -3.724326 -1.271245 -0.980100
# 12 -2.387255 -3.242584 -2.058586 -4.308760 -3.690690 -2.934147 -1.975015
# 13 -1.218163 -3.852684 -1.284127 -3.375398 -2.689127 -2.021764 -0.727897
# 14 -1.951872 -2.889127 -1.891733 -4.307753 -3.056107 -2.431022 -1.129398
# 15 -2.473722 -2.646163 -2.231590 -3.558215 -3.091789 -2.538454 -1.527540
# 16 -1.720610 -1.986022 -1.108286  0.815224  1.820636  4.760346  2.954965
# 17 -0.243773  1.210131  1.517715  0.610630  0.234063  3.542475  4.911103
# 18  0.201510 -0.794613  2.292787  0.390986  0.990747  1.216268  3.587108
# 19 -2.334105 -2.543195 -2.323684  0.792085  0.114277  3.005775  2.057245
# 20 -1.930542 -2.696522 -2.052171 -2.829461 -4.074559 -3.376360 -1.758840
# 21 -1.315156 -2.802702 -2.261008 -2.621889 -3.797837 -1.228447 -1.575827
# 22 -2.035664 -4.123087 -1.252495 -1.968987 -2.573363 -1.440835 -0.254491
# 23 -1.259839 -2.153226 -1.502431 -3.061487 -3.588544 -2.234923 -1.609541
# 24 -2.170957 -1.632104 -2.455399 -2.463910 -3.329747 -1.987388 -1.447099
# 25 -2.181275 -3.645949 -2.749816 -2.672624 -3.132241  0.185579  0.062894
# 26 -2.900056 -3.153139 -2.768411 -3.376482 -3.440448 -2.929351 -0.168987
# 27 -2.959325 -3.211134 -3.326302 -3.709166 -3.449374 -2.610799 -0.922881
# 28  0.504777 -0.910315 -1.629581 -2.266687 -1.914355 -0.592813 -0.817954
# 29 -1.090854 -2.557833 -1.919269 -2.449288 -1.857395  0.887342  0.463200
# 30 -0.673156 -1.772418 -0.366254 -1.435634 -1.933249 -0.424265 -0.417460
# 31 -0.531631 -1.520154  0.459016 -2.469946 -2.311340  0.139203 -0.638212
# 32  0.307190 -1.021550  1.991019  0.039434 -1.972769  1.646155  2.472602
# 33  3.935922  1.936539 -0.356225 -0.907458 -1.703260  1.550175  2.142498
# 34  1.112665  0.711728 -0.687811 -0.425767 -0.515595  2.472222  2.192585
# 35 -1.718498 -1.851880 -0.644825 -0.412860 -0.991518  0.754740  1.054369
# 36 -1.143350 -1.837990 -1.950915 -1.939609 -3.454777 -2.364993  0.298678
# 37 -3.300414 -2.135585 -1.928369  0.269635 -0.338531  0.732511  2.383146
# 38 -1.395282 -1.157988 -2.061419 -2.191103 -3.351986 -2.177315 -0.207489
# 39 -1.995192 -1.103653 -3.667362 -2.922241 -4.046789 -1.634121  0.011206
# 40  6.193453  4.150019  3.114976  1.903333 -2.287368  1.083255  4.180518
# 41  7.278126  3.906223  1.445613 -1.140537 -1.695880  1.628034  3.664088
# 42  2.635464  2.809928  3.989848  0.192416 -2.151609  1.435279  4.531375
# 43  4.736695  2.612483  1.950206  1.461668 -0.599978  4.051506  1.986416
# 44 -0.900061 -0.154180 -1.090187 -1.044051 -1.340245 -1.396554 -0.857316
# 45 -1.361295 -0.133915 -1.336876 -1.662538 -0.510987  0.887876  0.655693
# 46 -3.389311 -2.506297 -3.534836 -2.534022 -3.590243 -2.008490 -1.090697
# 47 -2.665489 -2.198300 -3.072881 -2.367354 -3.852197 -2.665658 -1.389509
# 48  1.985118  2.944847  1.237265  1.846766  2.240067  1.114341  1.154552
# 49  1.078588  2.054066  1.310366  0.256964  0.665413  1.959424  1.296816
#
#           37        38        39
# 0  -2.481059 -2.791023 -2.244865
# 1  -3.586074 -2.706395 -2.812933
# 2  -3.248326 -2.979813 -2.769281
# 3  -2.976706 -2.914763 -3.909605
# 4  -2.373389 -3.204345 -3.363193
# 5  -3.772603 -3.569510 -4.787323
# 6  -2.945964 -4.121965 -3.510513
# 7  -2.946774 -2.913152 -3.923706
# 8  -3.237412 -4.037536 -4.003767
# 9  -2.991815 -3.720481 -4.148329
# 10 -4.087718 -4.054740 -3.560002
# 11 -3.875573 -3.923644 -4.604771
# 12 -1.318242 -1.534859 -1.325751
# 13 -2.452416 -1.946813 -1.426459
# 14 -1.776879 -3.074241 -2.788808
# 15 -3.135894 -3.801238 -2.650141
# 16  0.111607 -0.752515 -1.284308
# 17  4.637895  2.276270 -0.617153
# 18  1.743506  1.517757  1.755406
# 19  0.662277  1.296270  1.566049
# 20 -2.906863 -3.204947 -3.409170
# 21 -2.997453 -3.080381 -3.495444
# 22 -2.717146 -3.634011 -3.410642
# 23 -2.212592 -2.207349 -3.091373
# 24 -3.343413 -2.142615 -3.888888
# 25 -2.394338 -2.621952 -2.446171
# 26 -1.116435 -0.033561 -0.784372
# 27 -3.045975 -2.543900 -2.605455
# 28 -0.945100 -3.051688 -1.823952
# 29  2.092109  0.123748  0.418165
# 30 -1.102653 -1.654609 -0.982137
# 31  0.588488 -1.013511 -1.898739
# 32  0.757326 -1.716301 -1.296842
# 33  0.774572 -1.230779 -0.858137
# 34  2.736108  0.969307  1.214890
# 35  1.658536 -0.873979 -2.020631
# 36 -1.058189 -0.337524 -0.325409
# 37  0.833519 -0.949942 -0.179258
# 38 -1.742043 -2.788416 -3.125000
# 39 -2.770940 -2.671198 -3.629413
# 40  3.431066  0.969346  0.144605
# 41  0.547687 -1.933110 -2.057331
# 42  2.239522  0.338202 -1.213463
# 43  0.638638 -1.188422  0.290454
# 44 -0.402505 -2.465899 -2.018805
# 45  0.653864 -0.846239 -1.870553
# 46 -3.107606 -4.755146 -3.054592
# 47 -1.183371 -2.658273 -2.198195
# 48  0.327648 -1.082427 -1.365471
# 49 -0.844955 -2.684399 -2.250904
#
# [50 rows x 44 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(dataframe.drop(['path','emotion','gender','actor'],axis=1)
                                                    , dataframe['emotion']
                                                    , test_size=0.3
                                                    , shuffle=True
                                                    , random_state=42
                                                   )

# Lets see how the data present itself before normalisation 
X_train[150:160]
# Out:
#                0          1          2          3          4          5  \
# 1507 -556.186584  63.398426  -7.535199  14.592493   8.701838   3.924429
# 1033 -501.659576  40.713284 -17.514589   4.574924 -11.315581 -12.481728
# 1097 -509.161316  38.850578  -1.835882   9.304722  -6.964986   4.798498
# 1469 -604.044434  72.271339  -9.245396  17.922968   8.336254   0.523125
# 543  -746.231201  58.421246  -7.258045   7.157975  -2.357727  -4.805716
# 1046 -715.503662  69.203720  19.233730  27.205339   5.285226  15.107376
# 4588 -455.742859  86.338509  11.563093   7.967887   4.676503  11.751726
# 2865 -329.235687  43.961327 -23.038237  20.582888 -19.054312   5.268102
# 30   -573.594360  49.186203  -5.265390  15.504213  -3.937147   1.563768
# 725  -501.892853  59.708794 -18.752121  15.756915  -4.094915 -21.821592
#
#               6          7          8         9  ...        30        31  \
# 1507  -5.859252  -1.513798  -5.679106  7.405304  ...  4.671828  5.907783
# 1033 -10.657444 -16.365210 -22.086533 -0.815869  ... -1.256361  1.789111
# 1097  -6.366741   3.762704 -11.002736  0.450350  ...  1.117864  2.690936
# 1469   0.082682   3.225629  -6.944763  3.703462  ... -0.287785 -0.114882
# 543  -17.117079  -7.776828  -8.964331  2.723106  ...  6.096379  8.956216
# 1046  -0.802234   3.110544  -4.094955  6.905212  ...  0.887249  1.239573
# 4588 -18.530741   8.897447 -22.486078  0.983861  ...  4.582048  3.303454
# 2865  -9.100691 -14.725112  -4.630383 -1.286420  ...  9.114408  3.612271
# 30    -8.442286  -3.646133 -16.220686 -1.598308  ... -0.673156 -1.772418
# 725   -7.618872   0.615160 -18.224157 -0.320319  ...  0.963091  2.579963
#
#             32        33        34        35        36        37         38  \
# 1507  5.078280  2.744928  1.482012  2.727428  2.668849  1.912292   2.300796
# 1033  1.132968 -2.519350 -3.571312  0.709451 -0.797680 -0.349582   2.913297
# 1097  2.194607  1.885185  1.165464 -0.632870 -1.298387  1.108223   0.442112
# 1469  0.953194  0.274394 -0.180504  0.603098  0.341869  0.349368  -0.365587
# 543   7.497740  8.636086  7.152712  2.712255  1.319895  0.781627   3.953298
# 1046 -1.426326 -1.105243 -2.362268 -1.278850 -1.713257 -0.751919  -2.218677
# 4588  2.342594  2.007040  2.138508  4.472968  3.181472  5.409222   9.948735
# 2865 -1.094308  0.847631  3.732956  3.237900  0.342025 -1.507976  -2.116951
# 30   -0.366254 -1.435634 -1.933249 -0.424265 -0.417460 -1.102653  -1.654609
# 725   0.747541  0.914231 -1.069245  1.982647  4.078440  7.654390  10.354730
#
#              39
# 1507   1.479813
# 1033  10.039142
# 1097   0.467524
# 1469  -1.026393
# 543    5.485705
# 1046  -2.971524
# 4588   9.959125
# 2865  -0.193578
# 30    -0.982137
# 725    8.325566
#
# [10 rows x 40 columns]

# %%
y_train.value_counts()
# Out:
# 3    551
# 0    545
# 4    534
# 6    533
# 7    424
# 2    415
# 5    411
# 1    263
# Name: emotion, dtype: int64

# %%
mean = np.mean(X_train, axis=0)
std = np.std(X_train, axis=0)

X_train = (X_train - mean)/std
X_test = (X_test - mean)/std

# Check the dataset now 
X_train.head()
# Out:
#              0         1         2         3         4         5         6  \
# 3992  0.620348  1.429633  0.902116 -0.258695  0.826235 -0.098448 -0.944982
# 3942  0.217969  1.789998  2.017981 -0.359569 -0.565307 -1.322534 -0.359769
# 2751  1.266544 -0.236147 -0.994866 -0.748304 -2.327632  0.260023  0.123062
# 4092  0.274949  1.408209  1.683918 -1.046155 -0.780828 -0.796001 -0.377063
# 564  -1.810111  0.260210 -0.426990 -0.172734 -0.361728 -0.484847 -1.417407
#
#              7         8         9  ...        30        31        32  \
# 3992  1.295247 -1.534813  0.010823  ... -0.585940 -1.133458 -0.421854
# 3942  1.198246 -1.504280  1.161064  ...  0.142399  0.284493  1.471809
# 2751 -0.201765 -0.822560  1.637019  ...  0.514240  0.905093 -0.018114
# 4092  2.192986 -0.868405  1.660470  ...  0.532461  0.628798  0.834033
# 564  -0.178203  0.205248  0.043218  ...  1.130341  1.464299  0.734969
#
#             33        34        35        36        37        38        39
# 3992 -0.462575  0.006447  0.151085  0.719931  0.937916  1.564189  1.116593
# 3942  1.005075  1.628698  1.185277  1.443630  0.791217  0.314278 -0.175237
# 2751  0.504307  0.097492  0.172124  0.318137  0.059210  0.087323 -0.116798
# 4092  0.188838  0.591369 -0.106399  0.431452  0.185472  1.330102  0.617407
# 564   0.644988 -0.230767 -0.420789 -0.546405 -0.123099 -0.325182 -0.629709
#
# [5 rows x 40 columns]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

# one hot encode the target 
lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(y_train))
y_test = np_utils.to_categorical(lb.fit_transform(y_test))

print(X_train.shape)
print(lb.classes_)
#print(y_train[0:10])
#print(y_test[0:10])

# Pickel the lb object for future use 
filename = 'labels'
outfile = open(filename,'wb')
pickle.dump(lb,outfile)
outfile.close()
# Out:
# (3676, 40)
# [0 1 2 3 4 5 6 7]

# %%
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)
X_train.shape
# Out:
# (3676, 40, 1)

# %% [raw]
# model = Sequential()
# model.add(Conv1D(64, 5, padding='same',input_shape=(X_train.shape[1],1)))  # X_train.shape[1] = No. of Columns
#
#
# model.add(Activation('relu'))
#
# model.add(Dropout(0.2))
#
# model.add(Flatten())
# model.add(Dense(8)) # Target class number
# model.add(Activation('softmax'))
#
# #opt = keras.optimizers.rmsprop(lr=0.00001, decay=1e-6)
# model.summary()
# #accuracy=89 val_acc=84 loss=0.30 val_loss=0.48

# %%
model = Sequential()
model.add(Conv1D(32, 5, padding='same',input_shape=(X_train.shape[1],1)))  # X_train.shape[1] = No. of Columns
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling1D(pool_size=(5)))
model.add(Dropout(0.2))
model.add(Conv1D(32, 5, padding='same'))
model.add(MaxPooling1D(pool_size=(5)))
model.add(Conv1D(64, 5, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(Conv1D(64, 5, padding='same'))
model.add(Flatten())

model.add(Dense(8)) # Target class number
model.add(Activation('softmax'))


#opt = keras.optimizers.rmsprop(lr=0.00001, decay=1e-6)
model.summary()
#loss: 0.6894 - accuracy: 0.7454 - val_loss: 0.6964 - val_accuracy: 0.7506
#better but less acc
# Out:
# WARNING:tensorflow:From C:\Users\SCS\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 40, 32)            192
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40, 32)            128
# _________________________________________________________________
# activation_1 (Activation)    (None, 40, 32)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 8, 32)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 32)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 8, 32)             5152
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 1, 32)             0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1, 64)             10304
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 64)             256
# _________________________________________________________________
# activation_2 (Activation)    (None, 1, 64)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 520
# _________________________________________________________________
# activation_3 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 16,552
# Trainable params: 16,360
# Non-trainable params: 192
# _________________________________________________________________

# %% [raw]
# model = Sequential()
# model.add(Conv1D(16, 5, padding='same',input_shape=(X_train.shape[1],1)))  # X_train.shape[1] = No. of Columns
# model.add(Activation('relu'))
# model.add(MaxPooling1D(pool_size=(5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Conv1D(64, 5, padding='same'))
# model.add(MaxPooling1D(pool_size=(5)))
# model.add(Conv1D(64, 5, padding='same'))
# model.add(Dropout(0.2))
# model.add(Flatten())
#
# model.add(Dense(8)) # Target class number
# model.add(Activation('softmax'))
#
#
# #opt = keras.optimizers.rmsprop(lr=0.00001, decay=1e-6)
# model.summary()
# #loss: 0.6333 - accuracy: 0.7753 - val_loss: 0.6214 - val_accuracy: 0.7697

# %% [raw]
# model = Sequential()
# model.add(Conv1D(32, 5, padding='same',input_shape=(X_train.shape[1],1)))  # X_train.shape[1] = No. of Columns
# model.add(Activation('relu'))
# model.add(MaxPooling1D(pool_size=(5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Conv1D(32, 5, padding='same'))
# model.add(MaxPooling1D(pool_size=(5)))
# model.add(Activation('relu'))
# model.add(Conv1D(64, 5, padding='same'))
# model.add(Dropout(0.2))
# model.add(Flatten())
# #model.add(Conv1D(64, 5, padding='same'))
# model.add(Dense(8)) # Target class number
# model.add(Activation('softmax'))
#
#
# #opt = keras.optimizers.rmsprop(lr=0.00001, decay=1e-6)
# model.summary()
# #loss: 0.5214 - accuracy: 0.8175 - val_loss: 0.6090 - val_accuracy: 0.7792
# #better model

# %% [raw]
# model = Sequential()
# model.add(Conv1D(32, 5, padding='same',input_shape=(X_train.shape[1],1)))  # X_train.shape[1] = No. of Columns
# model.add(Activation('relu'))
# model.add(MaxPooling1D(pool_size=(5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Conv1D(64, 5, padding='same'))
# model.add(Dropout(0.2))
# model.add(MaxPooling1D(pool_size=(5)))
# model.add(Conv1D(64, 5, padding='same'))
# #model.add(Dropout(0.2))
# model.add(Flatten())
# model.add(Dense(8)) # Target class number
# model.add(Activation('softmax'))
#
#
# #opt = keras.optimizers.rmsprop(lr=0.00001, decay=1e-6)
# model.summary()
# #loss: 0.4246 - accuracy: 0.8487 - val_loss: 0.5824 - val_accuracy: 0.8065

# %% [raw]
# model = Sequential()
# model.add(Conv1D(32, 5, padding='same',input_shape=(X_train.shape[1],1)))  # X_train.shape[1] = No. of Columns
# model.add(Activation('relu'))
# model.add(MaxPooling1D(pool_size=(5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
# model.add(Conv1D(64, 5, padding='same'))
# model.add(BatchNormalization())
# #model.add(Activation('relu'))
# model.add(Dropout(0.2))
# model.add(MaxPooling1D(pool_size=(5)))
# model.add(Conv1D(64, 5, padding='same'))
# model.add(Activation('relu'))
# model.add(Flatten())
# model.add(Dense(8)) # Target class number
# model.add(Activation('softmax'))
#
# #opt = keras.optimizers.rmsprop(lr=0.00001, decay=1e-6)
# model.summary()
# #loss: 0.5641 - accuracy: 0.8006 - val_loss: 0.5691 - val_accuracy: 0.8058
# #less convergence in graph

# %%
model.compile(loss='categorical_crossentropy',optimizer='RMSprop',metrics=['accuracy'])
model_history=model.fit(X_train, y_train, batch_size=16, epochs=40, validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\SCS\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 3676 samples, validate on 1576 samples
# Epoch 1/40
# 3676/3676 [==============================] - 3s 860us/step - loss: 1.5884 - accuracy: 0.4217 - val_loss: 1.5788 - val_accuracy: 0.4201
# Epoch 2/40
# 3676/3676 [==============================] - 3s 690us/step - loss: 1.1982 - accuracy: 0.5615 - val_loss: 1.0697 - val_accuracy: 0.6193
# Epoch 3/40
# 3676/3676 [==============================] - 2s 570us/step - loss: 1.0734 - accuracy: 0.6126 - val_loss: 0.9194 - val_accuracy: 0.6529
# Epoch 4/40
# 3676/3676 [==============================] - 2s 509us/step - loss: 0.9796 - accuracy: 0.6393 - val_loss: 0.8226 - val_accuracy: 0.6935
# Epoch 5/40
# 3676/3676 [==============================] - 1s 393us/step - loss: 0.9362 - accuracy: 0.6643 - val_loss: 0.8030 - val_accuracy: 0.6967
# Epoch 6/40
# 3676/3676 [==============================] - 1s 370us/step - loss: 0.8867 - accuracy: 0.6798 - val_loss: 0.7760 - val_accuracy: 0.7011
# Epoch 7/40
# 3676/3676 [==============================] - 1s 398us/step - loss: 0.8556 - accuracy: 0.6934 - val_loss: 0.7468 - val_accuracy: 0.7189
# Epoch 8/40
# 3676/3676 [==============================] - 1s 388us/step - loss: 0.8197 - accuracy: 0.6983 - val_loss: 0.7065 - val_accuracy: 0.7322
# Epoch 9/40
# 3676/3676 [==============================] - 1s 390us/step - loss: 0.8040 - accuracy: 0.7087 - val_loss: 0.6941 - val_accuracy: 0.7424
# Epoch 10/40
# 3676/3676 [==============================] - 1s 396us/step - loss: 0.7944 - accuracy: 0.7133 - val_loss: 0.6783 - val_accuracy: 0.7373
# Epoch 11/40
# 3676/3676 [==============================] - 1s 392us/step - loss: 0.7590 - accuracy: 0.7293 - val_loss: 0.7366 - val_accuracy: 0.7240
# Epoch 12/40
# 3676/3676 [==============================] - 1s 387us/step - loss: 0.7637 - accuracy: 0.7233 - val_loss: 0.6603 - val_accuracy: 0.7551
# Epoch 13/40
# 3676/3676 [==============================] - 1s 372us/step - loss: 0.7267 - accuracy: 0.7339 - val_loss: 0.6840 - val_accuracy: 0.7392
# Epoch 14/40
# 3676/3676 [==============================] - 1s 397us/step - loss: 0.7154 - accuracy: 0.7312 - val_loss: 0.6330 - val_accuracy: 0.7621
# Epoch 15/40
# 3676/3676 [==============================] - 1s 403us/step - loss: 0.7144 - accuracy: 0.7383 - val_loss: 0.6346 - val_accuracy: 0.7532
# Epoch 16/40
# 3676/3676 [==============================] - 1s 406us/step - loss: 0.6936 - accuracy: 0.7456 - val_loss: 0.6399 - val_accuracy: 0.7582
# Epoch 17/40
# 3676/3676 [==============================] - 1s 395us/step - loss: 0.6883 - accuracy: 0.7429 - val_loss: 0.6324 - val_accuracy: 0.7570
# Epoch 18/40
# 3676/3676 [==============================] - 1s 387us/step - loss: 0.7005 - accuracy: 0.7388 - val_loss: 0.6270 - val_accuracy: 0.7678
# Epoch 19/40
# 3676/3676 [==============================] - 1s 389us/step - loss: 0.6807 - accuracy: 0.7478 - val_loss: 0.6283 - val_accuracy: 0.7627
# Epoch 20/40
# 3676/3676 [==============================] - 1s 399us/step - loss: 0.6599 - accuracy: 0.7530 - val_loss: 0.6219 - val_accuracy: 0.7633
# Epoch 21/40
# 3676/3676 [==============================] - 1s 395us/step - loss: 0.6476 - accuracy: 0.7633 - val_loss: 0.6057 - val_accuracy: 0.7621
# Epoch 22/40
# 3676/3676 [==============================] - 1s 394us/step - loss: 0.6659 - accuracy: 0.7503 - val_loss: 0.5828 - val_accuracy: 0.7830
# Epoch 23/40
# 3676/3676 [==============================] - 1s 381us/step - loss: 0.6485 - accuracy: 0.7595 - val_loss: 0.5752 - val_accuracy: 0.7817
# Epoch 24/40
# 3676/3676 [==============================] - 1s 394us/step - loss: 0.6533 - accuracy: 0.7641 - val_loss: 0.5989 - val_accuracy: 0.7779
# Epoch 25/40
# 3676/3676 [==============================] - 1s 391us/step - loss: 0.6593 - accuracy: 0.7641 - val_loss: 0.5929 - val_accuracy: 0.7741
# Epoch 26/40
# 3676/3676 [==============================] - 1s 393us/step - loss: 0.6202 - accuracy: 0.7636 - val_loss: 0.5792 - val_accuracy: 0.7811
# Epoch 27/40
# 3676/3676 [==============================] - 1s 395us/step - loss: 0.6236 - accuracy: 0.7696 - val_loss: 0.5476 - val_accuracy: 0.7931
# Epoch 28/40
# 3676/3676 [==============================] - 1s 386us/step - loss: 0.6446 - accuracy: 0.7671 - val_loss: 0.5770 - val_accuracy: 0.7887
# Epoch 29/40
# 3676/3676 [==============================] - 1s 382us/step - loss: 0.6321 - accuracy: 0.7701 - val_loss: 0.5718 - val_accuracy: 0.7824
# Epoch 30/40
# 3676/3676 [==============================] - 1s 387us/step - loss: 0.5993 - accuracy: 0.7824 - val_loss: 0.5663 - val_accuracy: 0.7900
# Epoch 31/40
# 3676/3676 [==============================] - 1s 382us/step - loss: 0.6198 - accuracy: 0.7641 - val_loss: 0.6066 - val_accuracy: 0.7703
# Epoch 32/40
# 3676/3676 [==============================] - 1s 392us/step - loss: 0.6172 - accuracy: 0.7723 - val_loss: 0.5518 - val_accuracy: 0.7957
# Epoch 33/40
# 3676/3676 [==============================] - 1s 404us/step - loss: 0.6064 - accuracy: 0.7753 - val_loss: 0.5786 - val_accuracy: 0.7830
# Epoch 34/40
# 3676/3676 [==============================] - 2s 409us/step - loss: 0.6029 - accuracy: 0.7851 - val_loss: 0.5860 - val_accuracy: 0.7805
# Epoch 35/40
# 3676/3676 [==============================] - 2s 415us/step - loss: 0.5997 - accuracy: 0.7845 - val_loss: 0.5521 - val_accuracy: 0.7881
# Epoch 36/40
# 3676/3676 [==============================] - 2s 434us/step - loss: 0.5931 - accuracy: 0.7856 - val_loss: 0.5755 - val_accuracy: 0.7786
# Epoch 37/40
# 3676/3676 [==============================] - 2s 436us/step - loss: 0.6066 - accuracy: 0.7775 - val_loss: 0.5594 - val_accuracy: 0.7881
# Epoch 38/40
# 3676/3676 [==============================] - 2s 421us/step - loss: 0.5910 - accuracy: 0.7756 - val_loss: 0.5284 - val_accuracy: 0.7982
# Epoch 39/40
# 3676/3676 [==============================] - 2s 434us/step - loss: 0.5757 - accuracy: 0.7826 - val_loss: 0.5408 - val_accuracy: 0.7938
# Epoch 40/40
# 3676/3676 [==============================] - 2s 417us/step - loss: 0.5717 - accuracy: 0.7867 - val_loss: 0.5134 - val_accuracy: 0.8065

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print("Loss of the model is - " , model.evaluate(X_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 1576/1576 [==============================] - 0s 82us/step
# Loss of the model is -  0.5133698087960935
# 1576/1576 [==============================] - 0s 78us/step
# Accuracy of the model is -  80.64720630645752 %

# %%
# PREDICTIONS
pred = model.predict(X_test)
pred=pred.argmax(axis=1)
pred = pred.astype(int).flatten()
pred = (lb.inverse_transform((pred)))
pred = pd.DataFrame({'Predicted Values': pred})

# ACTUAL LABELS
y=y_test.argmax(axis=1)
y = y.astype(int).flatten()
y= (lb.inverse_transform((y)))
y = pd.DataFrame({'Actual Values': y})

# COMBINE BOTH 
finaldf = y.join(pred)
finaldf[140:150]
# Out:
#      Actual Values  Predicted Values
# 140              5                 5
# 141              3                 0
# 142              6                 3
# 143              0                 7
# 144              7                 7
# 145              0                 0
# 146              3                 3
# 147              1                 1
# 148              1                 1
# 149              4                 4

# %%
print(classification_report(y, pred, target_names = ['angry','calm','disgust','fear','happy','neutral','sad','surprise']))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.84      0.81      0.82       231
#         calm       0.67      0.82      0.74       113
#      disgust       0.82      0.81      0.81       177
#         fear       0.80      0.81      0.80       225
#        happy       0.82      0.76      0.79       242
#      neutral       0.92      0.86      0.89       177
#          sad       0.80      0.77      0.78       243
#     surprise       0.76      0.86      0.81       168
#
#     accuracy                           0.81      1576
#    macro avg       0.80      0.81      0.81      1576
# weighted avg       0.81      0.81      0.81      1576

# %%
cm = confusion_matrix(y, pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in lb.classes_] , columns = [i for i in lb.classes_])
ax = sns.heatmap(cm, linecolor='white', cmap='Purples', linewidth=1, annot=True, fmt='')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.savefig('Initial_Model_Confusion_Matrix.png')
plt.show()

# %%
# Save model and weights
model_name = 'Audio_Emotion_Model_2ds.h5'
save_dir = os.path.join(os.getcwd(), 'saved_models')

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Save model and weights at %s ' % model_path)

# Save the model to disk
model_json = model.to_json()
with open("model_json.json", "w") as json_file:
    json_file.write(model_json)
# Out:
# Save model and weights at C:\Users\SCS\FYP2\saved_models\Audio_Emotion_Model_2ds.h5

# %%
json_file = open('model_json.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# load weights into new model
loaded_model.load_weights("saved_models/Audio_Emotion_Model_2ds.h5")
print("Loaded model from disk")
 
# Keras optimiser
opt = keras.optimizers.rmsprop(lr=0.00001, decay=1e-6)
loaded_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
score = loaded_model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Loaded model from disk
# accuracy: 80.65%

# %%
from keras.utils.vis_utils import plot_model
plot_model(model)
